# %%
# %load_ext autoreload
# %autoreload 2
from confignb import *

X, y, pts, ks = h.load_data(DATA_DIR / 'ASCADv_clean.h5')
X = X.rename(columns=str)
# Out:
# INFO:2026-01-25 16:00:53,196:jax._src.xla_bridge:834: Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: libtpu.so: cannot open shared object file: No such file or directory
# 16:00:53: Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: libtpu.so: cannot open shared object file: No such file or directory

# %%
R = np.load("data/combined_nicv_results.npy")

# %%
fig, ax = plt.subplots(figsize=(12, 12))
sns.heatmap(R, cmap='inferno', vmin=0, vmax=0.01, square=True)
p.labs(ax, xlab="Feature 1", ylab="Feature 2", title="NICV")
# Out:
# <Axes: title={'center': 'NICV'}, xlabel='Feature 1', ylabel='Feature 2'>

# %%
idx = np.where(R > 0.004)[0]
idx
# Out:
# array([  59,   60,   64,   64,   65,  192,  193,  193, 1068, 1068, 1068,
#        1068, 1068, 1069, 1069, 1069])
