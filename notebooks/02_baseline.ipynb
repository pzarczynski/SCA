# %%
# %load_ext autoreload
# %autoreload 2
import config as cfg
from sca import plots, helpers as h
import logging
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
X, y, pts, ks = h.load_data('data/raw/ascadv.h5')

# %%
from sklearn.dummy import DummyClassifier
dummy = DummyClassifier(strategy='uniform')

score = h.cv(dummy, X, y, pts, ks, n_repeats=5, seed=cfg.SEED)
logging.info(f"Mean PI (Dummy, 2 splits, 5 repeats): {score:.2e}")
# Out:
# 12:09:40: [1] Mean PI: 0.000
# 12:09:40: [2] Mean PI: 0.000
# 12:09:41: [3] Mean PI: 0.000
# 12:09:42: [4] Mean PI: 0.000
# 12:09:42: [5] Mean PI: 0.000
# 12:09:43: [6] Mean PI: 0.000
# 12:09:43: [7] Mean PI: 0.000
# 12:09:44: [8] Mean PI: 0.000
# 12:09:45: [9] Mean PI: 0.000
# 12:09:45: [10] Mean PI: 0.000
# 12:09:45: Mean PI (Dummy, 2 splits, 5 repeats): 0.00e+00

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

pl_gnb = make_pipeline(StandardScaler(), GaussianNB())
score = h.cv(pl_gnb, X, y, pts, ks, n_repeats=5, seed=cfg.SEED)
logging.info(f"Mean PI (GNB, 2 splits, 5 repeats): {score:.2e}")
# Out:
# 12:11:06: [1] Mean PI: -94.118
# 12:12:11: [2] Mean PI: -89.436
# 12:14:37: [3] Mean PI: -86.981
# 12:17:26: [4] Mean PI: -89.851
# 12:20:08: [5] Mean PI: -97.113
# 12:22:19: [6] Mean PI: -89.745
# 12:24:27: [7] Mean PI: -91.630
# 12:26:35: [8] Mean PI: -90.590
# 12:28:43: [9] Mean PI: -85.009
# 12:31:03: [10] Mean PI: -84.646
# 12:31:03: Mean PI (GNB, 2 splits, 5 repeats): -8.99e+01
